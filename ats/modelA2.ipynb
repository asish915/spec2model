# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
df=pd.read_csv('train_A.csv')
df.fillna(df.median(numeric_only=True))
print(df)
# Out:
#         id  order_hour day_of_week restaurant_type  cuisine_type  distance_km  \
# 0        1           6      sunday            cafe  south_indian         10.7
# 1        2          19      friday   casual_dining       dessert          1.1
# 2        3          14      sunday     fine_dining       dessert         13.6
# 3        4          10      monday   cloud_kitchen  south_indian          7.5
# 4        5           7    thursday     fine_dining       chinese          7.2
# ...    ...         ...         ...             ...           ...          ...
# 2995  2996           5     tuesday   cloud_kitchen         other          3.5
# 2996  2997          14      monday   casual_dining  pizza_burger         14.2
# 2997  2998          17   wednesday            cafe         other          0.8
# 2998  2999          23      friday   casual_dining       italian         14.5
# 2999  3000          10      sunday   cloud_kitchen         other          2.7
#
# ...

# %%
def detect_categorical_columns(df, unique_threshold=0.5):
    categorical_cols = []
    total_rows = len(df)

    for col in df.columns:
        if pd.api.types.is_bool_dtype(df[col]) or pd.api.types.is_any_real_numeric_dtype(df[col]):
            continue
        if pd.api.types.is_object_dtype(df[col]) or pd.api.types.is_categorical_dtype(df[col]):
            categorical_cols.append(col)
        else:
            unique_ratio = df[col].nunique(dropna=True) / total_rows
            if unique_ratio <= unique_threshold:
                categorical_cols.append(col)

    return categorical_cols

if __name__ == "__main__":
    cat_columns = detect_categorical_columns(df)
    print("Categorical columns detected:", cat_columns)
# Out:
# Categorical columns detected: ['day_of_week', 'restaurant_type', 'cuisine_type', 'weather_condition', 'traffic_density', 'area_type', 'is_late']
