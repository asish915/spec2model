# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,f1_score

# %%
df=pd.read_csv('/Users/umesh/Desktop/spec2model/problems/PROBLEM_A/dummy_A.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       80 non-null     int64
#  1   order_hour               80 non-null     int64
#  2   day_of_week              80 non-null     object
#  3   restaurant_type          80 non-null     object
#  4   cuisine_type             80 non-null     object
#  5   distance_km              80 non-null     float64
#  6   estimated_delivery_min   80 non-null     int64
#  7   order_value_inr          80 non-null     float64
#  8   num_items                80 non-null     int64
#  9   is_peak_hour             80 non-null     bool
#  10  weather_condition        80 non-null     object
#  11  traffic_density          80 non-null     object
#  12  delivery_partner_rating  80 non-null     float64
#  13  delivery_partner_orders  80 non-null     float64
#  14  restaurant_rating        80 non-null     float64
#  15  restaurant_avg_prep_min  80 non-null     float64
#  16  is_promo_order           80 non-null     bool
#  17  area_type                80 non-null     object
#  18  is_late                  80 non-null     object
# dtypes: bool(2), float64(6), int64(4), object(7)
# memory usage: 10.9+ KB
